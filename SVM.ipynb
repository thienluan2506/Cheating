# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/YOLOv7_pose/yolov7-pose-estimation
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
# /content/gdrive/MyDrive/YOLOv7_pose/yolov7-pose-estimation

# %%
df = pd.read_csv("test.csv")

# %%
columnName = []
for i in range(17):
  columnName.append("kp" + str(i) + "_X")
  columnName.append("kp" + str(i) + "_Y")
  columnName.append("kp" + str(i) + "_Confi")

# %%
X = df[columnName]
Y = df['label']
lc = LabelEncoder()
lc = lc.fit(Y)
Y = lc.transform(Y)
print(X.shape)
print(Y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
# Out:
# (6545, 51)
# (6545,)

# %%
model = svm.LinearSVC()
model.fit(X_train, y_train)
prediction = model.predict(X_test)

# %%
print(f"Test Set Accuracy : {accuracy_score(y_test, prediction) * 100} %\n\n")
print(f"calssification report {classification_report(y_test, prediction)}")
# Out:
# Test Set Accuracy : 95.49274255156608 %
#
#
# calssification report               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       705
#            1       0.93      0.98      0.95       604
#
#     accuracy                           0.95      1309
#    macro avg       0.95      0.96      0.95      1309
# weighted avg       0.96      0.95      0.95      1309
